# %% [markdown]
# # L01 - Pandas Visualizations - Exercises

# %%
# import pandas package before trying out the exercises below
import pandas as pd

# %% [markdown]
# ## Exercise 1: Analyze a Stock's Price History
# Dataset: StockData/AAPL.csv (or any other ticker in StockData folder)
#
# Task:
# 1. Load the dataset into a DataFrame.
# 2. Plot the closing price over time using a line chart over the last 30 days.
# 3. Create a bar plot of trading volume for the last 30 days.
# 4. Add a 20-day, 50-day and 200-day moving average (as new columns) and overlay them on the closing price chart over the last 180 days.
#
# Learning goals: Line and bar charts in Pandas, adding derived columns for moving averages, working with datetime.

# %%
#Your answer here

# %% [markdown]
# ## Exercise 2: Sector Deal Volumes Over Time
#
# Dataset: Deals.xlsx
#
# Task:
# 1. Group the deals by deal type and month.
# 2. Create a stacked bar chart showing total deal size per month, broken down by type of deal.
# 3. Create a horizontal bar chart showing total deal size by lead underwriter (top 10 only), sorted with the largest deal size at the top of the graph.
#
# Learning goals: Aggregation with groupby(), stacked bar charts, sorting and filtering for visual clarity.

# %%
#Your answer here
