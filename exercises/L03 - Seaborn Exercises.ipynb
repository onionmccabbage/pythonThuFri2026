# %% [markdown]
# # L03 - Seaborn - Exercises

# %%
# import pandas and matplotlib packages before trying out the exercises below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Exercise 1: Comparing Categorical Data
# Dataset: Dataset: Deals.xlsx
#
# Task:
# 1. Import and filter the Deals data set for Goldman Sachs and J.P. Morgan.
# 2. Create a side-by-side bar graph showing the count of deals by Type of deal. Hint: You can use the seaborn `countplot` function instead of creating a pivot and then plotting a normal bar chart.
# 3. Answer the following questions using the visualization you created:
#     1. In what types of deals did Goldman outperform J.P. Morgan?
#     2. Which category did J.P. Morgan have more than 15 deals in the data set?
#     3. In how many categories did Goldman have 0 deals?
#
# Learning goals: Comparing categorical data with seaborn bar charts and using `hue` argument.

# %%
#Your answer here

# %% [markdown]
# ## Exercise 2: Exploring Outliers with Box-and-Whiskers Plots
#
# Dataset:
# - sp500_Cos_ValMetrics.csv - list of valuation metrics and other metrics of S&P 500 companies
# - sp500_SectorData.csv - table of sectors and company names of S&P 500 companies
#
# Task:
# 1. Load and merge the two data sets using the stock symbol column as the common column. Sort the data alphabetically by GICS sector.
# 2. Using Seaborn, create a box-and-whiskers plot (`boxplot`) that shows the betas of the companies broken down by GICS sector.
# 3. Create another box-and-whiskers plot that shows the EV/Revenue by GICS sector. Which sector has the largest outliers?
#     1. Explore the data to understand which companies are those outliers. (Hint: Perform a filter on the EV/Revenue column).
#     2. What do you notice is common about these companies?
# 4. Recreate the EV/Revenue by sector boxplot again without the outliers found  in the previous question and answer the following questions using the graph:
#     1. Which sector has the largest median EV/Revenue?
#     2. Which sector has the smallest range in EV/Revenue, excluding any outliers?
#     3. Which sector has companies with negative EV/Revenue?
# 5. Create a scatter plot of EV/Revenue vs Beta of the data without the outliers identified in question 3. Break out the series in different colors by sector. (Hint: use `hue` argument).
#     1. Which sectors are primarily in the bottom left quadrant of the graph (low EV/Revenue and low betas)?
#
# Learning goals: Practice finding outliers with boxplots in Seaborn and identifying trends in sectors.

# %%
#Your answer here
