# %% [markdown]
# # L04 - Plotly - Exercises

# %%
# import pandas and matplotlib packages before trying out the exercises below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Exercise 1: Comparing Distributions of Stock Returns
# Dataset: Multiple ticker files in StockData folder.
#
# Task:
# 1. Load the stock data for the following tickers: AAPL, DIS, HD, INTC, NKE, MSFT. Use loops to automate the process to load the data. Only store data between 2014 and 2018.
# 2. Calculate the daily returns for each of the tickers using the adjusted close price and merge all the tables into one DataFrame.
# 2. Create a plotly box plot of the returns of all the tickers.
# 3. Create a plotly histogram of the returns of all the tickers. Experiment with plotting all the histograms overalyed on top of each other vs. creating multiple subplots side by side or stacked. (Hint: use `face_col` or `face_row` arguments.)
#
# Learning goals: Practice creating multiple box plots and histograms with plotly to compare distribution of returns across different companies.

# %%
#Your answer here

# %% [markdown]
# ## Exercise 2: Sector Overview of S&P 500 Constituents
#
# Dataset:
# - sp500_Cos_ValMetrics.csv - list of valuation metrics and other metrics of S&P 500 companies
# - sp500_SectorData.csv - table of sectors and company names of S&P 500 companies
#
# Task:
# 1. Load and merge the two data sets using the stock symbol column as the common column. Sort the data alphabetically by GICS sector.
# 2. Apply a "cleaning up" function on the Market Cap column to remove the B's and T's and convert the billions and trillions values into US$ billions.
# 3. Create a sunburst and a treemap graph that shows total Market Cap broken down in the following layers: 'GICS Sector', 'GICS Sub-Industry', 'Symbol'
# 4. Create a scatter bubble chart where the x-axis is Beta, y-axis is EV/Revenue, and the size of the bubbles represent the Market Cap. Also display the security name, symbol and sub-industry when hovering your mouse over the bubbles.
#
# Learning goals: Practice creating whole-of-parts charts with plotly to get a quick overview of sector and company weights in an ETF or index.

# %%
#Your answer here
